# %%
import pandas as pd

# Caminho do arquivo CSV
caminho_arquivo = '../data/microdados_censo_da_educacao_superior_2023/dados/MICRODADOS_ED_SUP_IES_2023.CSV'

# Ler o arquivo CSV
df = pd.read_csv(caminho_arquivo, sep=';', encoding='latin-1')

# Imprimir as colunas do arquivo
print("Colunas do arquivo:")
print(df.columns.tolist())

# Imprimir informações básicas
print(f"\nNúmero de linhas: {len(df)}")
print(f"Número de colunas: {len(df.columns)}")
# Out:
# Colunas do arquivo:
# ...

# %%
import matplotlib.pyplot as plt

# Contar a quantidade de IES por estado
ies_por_uf = df['SG_UF_IES'].value_counts().sort_values(ascending=False)

# Plotar gráfico de barras
plt.figure(figsize=(12, 6))
bars = plt.bar(ies_por_uf.index, ies_por_uf.values)
plt.title('Quantidade de IES por Estado (UF)')
plt.xlabel('Estado (UF)')
plt.ylabel('Quantidade de IES')
plt.xticks(rotation=45)

# Adicionar labels em cada barra
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{int(height)}',
             ha='center', va='bottom')

plt.tight_layout()
plt.show()

# Imprimir os dados
print("\nQuantidade de IES por estado:")
print(ies_por_uf)
# Out:
# Quantidade de IES por estado:
# SG_UF_IES
# SP    586
# MG    310
# PR    174
# BA    149
# RJ    128
# GO    127
# RS    120
# PE    118
# SC    102
# CE    101
# PA     77
# MT     72
# ES     69
# MA     65
# DF     61
# PI     48
# PB     45
# AM     32
# RO     32
# AL     30
# MS     30
# RN     26
# TO     23
# SE     22
# AP     15
# AC      9
# RR      9
# Name: count, dtype: int64

# %%
# Caminho do arquivo CSV de cursos
caminho_cursos = '../data/microdados_censo_da_educacao_superior_2023/dados/MICRODADOS_CADASTRO_CURSOS_2023.CSV'

# Ler o arquivo CSV de cursos
df_cursos = pd.read_csv(caminho_cursos, sep=';', encoding='latin-1')

# Imprimir as colunas do arquivo de cursos
print("Colunas do arquivo de cursos:")
print(df_cursos.columns.tolist())

# Verificar se CO_IES está presente
if 'CO_IES' in df_cursos.columns:
    print("\n✓ CO_IES encontrado no dataset de cursos (chave estrangeira)")
else:
    print("\n✗ CO_IES não encontrado no dataset de cursos")

# Imprimir informações básicas
print(f"\nNúmero de linhas: {len(df_cursos)}")
print(f"Número de colunas: {len(df_cursos.columns)}")
# Out:
# /tmp/ipykernel_13840/3656004531.py:5: DtypeWarning: Columns (0: NO_REGIAO, 1: NO_UF, 2: SG_UF, 3: NO_MUNICIPIO) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_cursos = pd.read_csv(caminho_cursos, sep=';', encoding='latin-1')
# Colunas do arquivo de cursos:
# ...

# %%
# Merge entre os dataframes de IES e cursos usando CO_IES
df_merged = pd.merge(df_cursos, df[['CO_IES', 'SG_UF_IES']], on='CO_IES', how='left')

# Imprimir informações do merge
print(f"DataFrame mergeado: {len(df_merged)} linhas")
print(f"Colunas disponíveis no merge: {len(df_merged.columns)}")
# Out:
# DataFrame mergeado: 671610 linhas
# Colunas disponíveis no merge: 203

# %%
# Gráfico: QT_INSCRITO_TOTAL por estado
inscrito_uf = df_merged.groupby('SG_UF_IES')['QT_INSCRITO_TOTAL'].sum().sort_values(ascending=False)

plt.figure(figsize=(12, 6))
bars = plt.bar(inscrito_uf.index, inscrito_uf.values)
plt.title('Total de Inscritos por Estado')
plt.xlabel('Estado (UF)')
plt.ylabel('Total de Inscritos')
plt.xticks(rotation=45)

# Adicionar labels em cada barra
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{int(height):,}',
             ha='center', va='bottom')

plt.tight_layout()
plt.show()

print("\nTotal de inscritos por estado:")
print(inscrito_uf)
# Out:
# Total de inscritos por estado:
# SG_UF_IES
# SP    3607591
# PR    2254338
# RJ    1579067
# SC    1024248
# MG     990732
# BA     562613
# CE     483145
# RS     474008
# PE     418143
# PA     372929
# DF     357345
# GO     336300
# MS     267701
# MA     259989
# PB     229584
# ES     220574
# MT     182452
# AM     161844
# PI     141425
# RN     129069
# AL     128843
# TO      76622
# RO      64940
# AC      56996
# SE      54388
# AP      53191
# RR      26612
# Name: QT_INSCRITO_TOTAL, dtype: int64

# %%
# Gráfico: QT_INSCRITO_TOTAL_EAD por estado
inscrito_ead_uf = df_merged.groupby('SG_UF_IES')['QT_INSCRITO_TOTAL_EAD'].sum().sort_values(ascending=False)

plt.figure(figsize=(12, 6))
bars = plt.bar(inscrito_ead_uf.index, inscrito_ead_uf.values)
plt.title('Total de Inscritos EAD por Estado')
plt.xlabel('Estado (UF)')
plt.ylabel('Total de Inscritos EAD')
plt.xticks(rotation=45)

# Adicionar labels em cada barra
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{int(height):,}',
             ha='center', va='bottom')

plt.tight_layout()
plt.show()

print("\nTotal de inscritos EAD por estado:")
print(inscrito_ead_uf)
# Out:
# Total de inscritos EAD por estado:
# SG_UF_IES
# PR    1824971
# SP    1494025
# RJ     802015
# SC     757569
# MG     163435
# RS     131263
# DF     118066
# MS     107323
# PE     107009
# CE      87528
# BA      52825
# GO      39543
# ES      36047
# PB      27522
# MA      22460
# PA      22022
# RN      16969
# PI      16168
# SE      12658
# AM      11541
# MT       8704
# AL       7275
# RO       5528
# AC       5165
# TO       5148
# RR       4637
# AP        150
# Name: QT_INSCRITO_TOTAL_EAD, dtype: int64

# %%
# Gráfico: QT_ING por estado
ing_uf = df_merged.groupby('SG_UF_IES')['QT_ING'].sum().sort_values(ascending=False)

plt.figure(figsize=(12, 6))
bars = plt.bar(ing_uf.index, ing_uf.values)
plt.title('Total de Ingressos por Estado')
plt.xlabel('Estado (UF)')
plt.ylabel('Total de Ingressos')
plt.xticks(rotation=45)

# Adicionar labels em cada barra
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{int(height):,}',
             ha='center', va='bottom')

plt.tight_layout()
plt.show()

print("\nTotal de ingressos por estado:")
print(ing_uf)
# Out:
# Total de ingressos por estado:
# SG_UF_IES
# PR    1439076
# SP    1166503
# SC     582030
# RJ     490460
# MG     208929
# RS     129313
# PE     123784
# BA      90662
# MS      89326
# CE      87565
# DF      87529
# GO      70355
# PA      54482
# PB      46960
# ES      44502
# AM      43543
# MA      41480
# RN      37613
# MT      35185
# PI      28973
# AL      23847
# SE      22259
# RO      16677
# TO      14115
# AC       7174
# AP       6633
# RR       5217
# Name: QT_ING, dtype: int64

# %%
# Gráfico: QT_ING_0_17 por estado
ing_0_17_uf = df_merged.groupby('SG_UF_IES')['QT_ING_0_17'].sum().sort_values(ascending=False)

plt.figure(figsize=(12, 6))
bars = plt.bar(ing_0_17_uf.index, ing_0_17_uf.values)
plt.title('Total de Ingressos (0-17 anos) por Estado')
plt.xlabel('Estado (UF)')
plt.ylabel('Total de Ingressos (0-17 anos)')
plt.xticks(rotation=45)

# Adicionar labels em cada barra
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{int(height):,}',
             ha='center', va='bottom')

plt.tight_layout()
plt.show()

print("\nTotal de ingressos (0-17 anos) por estado:")
print(ing_0_17_uf)
# Out:
# Total de ingressos (0-17 anos) por estado:
# SG_UF_IES
# SC    3558
# PR    1309
# PB     663
# SP     621
# PE     597
# GO     512
# CE     510
# RJ     483
# BA     453
# MG     423
# PA     342
# MA     334
# AM     216
# PI     204
# DF     191
# TO     185
# SE     134
# MS     126
# RN      76
# RS      70
# AL      70
# MT      65
# ES      62
# AP      24
# AC      22
# RO      21
# RR      16
# Name: QT_ING_0_17, dtype: int64

# %%
# Gráfico: QT_ING_18_24 por estado
ing_18_24_uf = df_merged.groupby('SG_UF_IES')['QT_ING_18_24'].sum().sort_values(ascending=False)

plt.figure(figsize=(12, 6))
bars = plt.bar(ing_18_24_uf.index, ing_18_24_uf.values)
plt.title('Total de Ingressos (18-24 anos) por Estado')
plt.xlabel('Estado (UF)')
plt.ylabel('Total de Ingressos (18-24 anos)')
plt.xticks(rotation=45)

# Adicionar labels em cada barra
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{int(height):,}',
             ha='center', va='bottom')

plt.tight_layout()
plt.show()

print("\nTotal de ingressos (18-24 anos) por estado:")
print(ing_18_24_uf)
# Out:
# Total de ingressos (18-24 anos) por estado:
# SG_UF_IES
# SP    519776
# PR    498828
# SC    198134
# RJ    192635
# MG    126554
# RS     71034
# PE     62077
# BA     58366
# CE     52052
# DF     47530
# GO     45899
# MS     37149
# PA     32942
# PB     29407
# ES     26477
# MA     26098
# AM     25501
# MT     22152
# RN     21565
# PI     18503
# AL     15584
# SE     13724
# RO     10105
# TO      9704
# AC      4584
# AP      4446
# RR      3031
# Name: QT_ING_18_24, dtype: int64

# %%
# Gráfico: QT_MAT por estado
mat_uf = df_merged.groupby('SG_UF_IES')['QT_MAT'].sum().sort_values(ascending=False)

plt.figure(figsize=(12, 6))
bars = plt.bar(mat_uf.index, mat_uf.values)
plt.title('Total de Matriculados por Estado')
plt.xlabel('Estado (UF)')
plt.ylabel('Total de Matriculados')
plt.xticks(rotation=45)

# Adicionar labels em cada barra
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{int(height):,}',
             ha='center', va='bottom')

plt.tight_layout()
plt.show()

print("\nTotal de matriculados por estado:")
print(mat_uf)
# Out:
# Total de matriculados por estado:
# SG_UF_IES
# SP    2331283
# PR    2080122
# SC    1065152
# RJ     948461
# MG     600342
# RS     313799
# PE     288671
# BA     281101
# CE     248858
# DF     214852
# GO     179294
# PA     164485
# MA     149089
# MS     134670
# AM     132211
# PB     132156
# ES     116979
# RN     108656
# PI     100004
# MT      99551
# AL      73751
# SE      59546
# TO      48264
# RO      45952
# AP      24627
# AC      19233
# RR      16108
# Name: QT_MAT, dtype: int64

# %%
# Gráfico: QT_MAT_0_17 por estado
mat_0_17_uf = df_merged.groupby('SG_UF_IES')['QT_MAT_0_17'].sum().sort_values(ascending=False)

plt.figure(figsize=(12, 6))
bars = plt.bar(mat_0_17_uf.index, mat_0_17_uf.values)
plt.title('Total de Matriculados (0-17 anos) por Estado')
plt.xlabel('Estado (UF)')
plt.ylabel('Total de Matriculados (0-17 anos)')
plt.xticks(rotation=45)

# Adicionar labels em cada barra
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{int(height):,}',
             ha='center', va='bottom')

plt.tight_layout()
plt.show()

print("\nTotal de matriculados (0-17 anos) por estado:")
print(mat_0_17_uf)
# Out:
# Total de matriculados (0-17 anos) por estado:
# SG_UF_IES
# SC    3977
# PR     804
# PB     614
# PE     532
# CE     502
# SP     487
# GO     469
# BA     445
# RJ     412
# MG     368
# PA     311
# MA     304
# PI     193
# AM     192
# DF     177
# TO     172
# SE     115
# MS      85
# RN      68
# AL      62
# ES      58
# RS      56
# MT      44
# AC      23
# AP      22
# RO      20
# RR      14
# Name: QT_MAT_0_17, dtype: int64

# %%
# Gráfico: QT_MAT_18_24 por estado
mat_18_24_uf = df_merged.groupby('SG_UF_IES')['QT_MAT_18_24'].sum().sort_values(ascending=False)

plt.figure(figsize=(12, 6))
bars = plt.bar(mat_18_24_uf.index, mat_18_24_uf.values)
plt.title('Total de Matriculados (18-24 anos) por Estado')
plt.xlabel('Estado (UF)')
plt.ylabel('Total de Matriculados (18-24 anos)')
plt.xticks(rotation=45)

# Adicionar labels em cada barra
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{int(height):,}',
             ha='center', va='bottom')

plt.tight_layout()
plt.show()

print("\nTotal de matriculados (18-24 anos) por estado:")
print(mat_18_24_uf)
# Out:
# Total de matriculados (18-24 anos) por estado:
# SG_UF_IES
# SP    1049581
# PR     682206
# RJ     370795
# MG     350895
# SC     349323
# RS     162943
# BA     155807
# PE     142294
# CE     137506
# DF     115049
# GO     112266
# PA      89947
# PB      80545
# MA      76662
# AM      66806
# ES      66685
# MS      62644
# PI      57893
# RN      57713
# MT      57564
# AL      41850
# SE      35339
# TO      28299
# RO      24963
# AP      12626
# AC      11060
# RR       8342
# Name: QT_MAT_18_24, dtype: int64

# %%
# Merge de dados por estado: QT_ING, QT_ING_0_17, QT_ING_18_24 (2023) e QT_MAT_MED (2022)

# Carregar dados do Censo Escolar 2022 para QT_MAT_MED
df_2022 = pd.read_csv('../data/microdados_censo_escolar_2022/microdados/dados/microdados_ed_basica_2022.csv', encoding='latin-1', sep=';', low_memory=False)

# Agrupar QT_MAT_MED por estado (2022)
mat_med_2022 = df_2022.groupby('SG_UF')['QT_MAT_MED'].sum().reset_index()
mat_med_2022.columns = ['SG_UF', 'QT_MAT_MED_2022']

# Carregar dados do Censo Superior 2023 para QT_ING
df_ies_2023 = pd.read_csv('../data/microdados_censo_da_educacao_superior_2023/dados/MICRODADOS_ED_SUP_IES_2023.CSV', sep=';', encoding='latin-1')
df_cursos_2023 = pd.read_csv('../data/microdados_censo_da_educacao_superior_2023/dados/MICRODADOS_CADASTRO_CURSOS_2023.CSV', sep=';', encoding='latin-1', low_memory=False)

# Merge IES e cursos 2023
df_merged_2023 = pd.merge(df_cursos_2023, df_ies_2023[['CO_IES', 'SG_UF_IES']], on='CO_IES', how='left')

# Agrupar QT_ING, QT_ING_0_17, QT_ING_18_24 por estado (2023)
ing_2023 = df_merged_2023.groupby('SG_UF_IES')[['QT_ING', 'QT_ING_0_17', 'QT_ING_18_24']].sum().reset_index()
ing_2023.columns = ['SG_UF', 'QT_ING_2023', 'QT_ING_0_17_2023', 'QT_ING_18_24_2023']

# Merge dos dois datasets por estado
df_merge_estado = pd.merge(mat_med_2022, ing_2023, on='SG_UF', how='outer')

# Preencher NaN com 0
df_merge_estado = df_merge_estado.fillna(0)

print("Dados mesclados por estado:")
print(df_merge_estado)

print("\nResumo estatístico:")
print(df_merge_estado.describe())
# Out:
# Dados mesclados por estado:
#    SG_UF  QT_MAT_MED_2022  QT_ING_2023  QT_ING_0_17_2023  QT_ING_18_24_2023
# 0     AC          41636.0         7174                22               4584
# 1     AL         127502.0        23847                70              15584
# 2     AM         199896.0        43543               216              25501
# 3     AP          32873.0         6633                24               4446
# 4     BA         569637.0        90662               453              58366
# 5     CE         359427.0        87565               510              52052
# 6     DF         114414.0        87529               191              47530
# 7     ES         127054.0        44502                62              26477
# 8     GO         249164.0        70355               512              45899
# 9     MA         277358.0        41480               334              26098
# 10    MG         707944.0       208929               423             126554
# ...

# %%
# Calcular porcentagem de alunos do ensino médio (2022) que ingressam no ensino superior (2023)

# Calcular total de ingressantes no ensino superior (0-17 + 18-24 anos)
df_merge_estado['QT_ING_TOTAL_2023'] = df_merge_estado['QT_ING_0_17_2023'] + df_merge_estado['QT_ING_18_24_2023']

# Calcular porcentagem de transição do ensino médio para superior
df_merge_estado['PORC_TRANSICAO_MED_SUP'] = (df_merge_estado['QT_ING_TOTAL_2023'] / df_merge_estado['QT_MAT_MED_2022']) * 100

# Ordenar por porcentagem
df_merge_estado_sorted = df_merge_estado.sort_values('PORC_TRANSICAO_MED_SUP', ascending=False)

print("Porcentagem de alunos do ensino médio (2022) que ingressaram no ensino superior (2023):")
print(df_merge_estado_sorted[['SG_UF', 'QT_MAT_MED_2022', 'QT_ING_TOTAL_2023', 'PORC_TRANSICAO_MED_SUP']].to_string(index=False))

# Criar gráfico de barras
plt.figure(figsize=(14, 8))
bars = plt.bar(df_merge_estado_sorted['SG_UF'], df_merge_estado_sorted['PORC_TRANSICAO_MED_SUP'], color='#2E86AB', alpha=0.7)

plt.title('Porcentagem de Alunos do Ensino Médio (2022) que Ingressaram no Ensino Superior (2023)', fontsize=14, fontweight='bold')
plt.xlabel('Estado (UF)', fontsize=12)
plt.ylabel('Porcentagem de Transição (%)', fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y', alpha=0.3)

# Adicionar labels com o valor da porcentagem em cada barra
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{height:.1f}%',
             ha='center', va='bottom', fontsize=9, fontweight='bold')

plt.tight_layout()
plt.show()

# Exibir estatísticas
print(f"\n{'='*70}")
print(f"ESTATÍSTICAS - TRANSIÇÃO ENSINO MÉDIO PARA SUPERIOR (2022 -> 2023)")
print(f"{'='*70}")
print(f"\nMédia: {df_merge_estado['PORC_TRANSICAO_MED_SUP'].mean():.2f}%")
print(f"Mediana: {df_merge_estado['PORC_TRANSICAO_MED_SUP'].median():.2f}%")
print(f"Desvio Padrão: {df_merge_estado['PORC_TRANSICAO_MED_SUP'].std():.2f}%")
print(f"Valor Mínimo: {df_merge_estado['PORC_TRANSICAO_MED_SUP'].min():.2f}%")
print(f"Valor Máximo: {df_merge_estado['PORC_TRANSICAO_MED_SUP'].max():.2f}%")
# Out:
# Porcentagem de alunos do ensino médio (2022) que ingressaram no ensino superior (2023):
# SG_UF  QT_MAT_MED_2022  QT_ING_TOTAL_2023  PORC_TRANSICAO_MED_SUP
#    PR         428566.0             500137              116.700112
#    SC         264642.0             201692               76.213148
#    DF         114414.0              47721               41.709057
#    MS         104448.0              37275               35.687615
#    RJ         596206.0             193118               32.391153
#    SP        1778846.0             520397               29.254753
#    ES         127054.0              26539               20.887969
#    PB         144453.0              30070               20.816459
#    RS         365084.0              71104               19.476066
#    GO         249164.0              46411               18.626688
#    PE         342004.0              62674               18.325517
#    MG         707944.0             126977               17.936023
# ...

# %%
# Salvar df_merge_estado em arquivo CSV
caminho_saida = '../data/df_merge_estado.csv'
df_merge_estado.to_csv(caminho_saida, index=False, encoding='utf-8')

print(f"DataFrame salvo com sucesso em: {caminho_saida}")
print(f"Número de linhas: {len(df_merge_estado)}")
print(f"Número de colunas: {len(df_merge_estado.columns)}")
print(f"\nColunas salvas: {df_merge_estado.columns.tolist()}")
# Out:
# DataFrame salvo com sucesso em: ../data/df_merge_estado.csv
# Número de linhas: 27
# Número de colunas: 7
#
# Colunas salvas: ['SG_UF', 'QT_MAT_MED_2022', 'QT_ING_2023', 'QT_ING_0_17_2023', 'QT_ING_18_24_2023', 'QT_ING_TOTAL_2023', 'PORC_TRANSICAO_MED_SUP']

# %%
# Gráfico: Quantidade de IES por estado (ordenado do maior para o menor)
plt.figure(figsize=(12, 6))
bars = plt.bar(ies_por_uf.index, ies_por_uf.values, color='#4A90E2', alpha=0.7)
plt.title('Quantidade de IES por Estado (UF)', fontsize=14, fontweight='bold')
plt.xlabel('Estado (UF)', fontsize=12)
plt.ylabel('Quantidade de IES', fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y', alpha=0.3)

# Adicionar labels em cada barra
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{int(height)}',
             ha='center', va='bottom', fontsize=9, fontweight='bold')

plt.tight_layout()
plt.show()

print("\nQuantidade de IES por estado (ordenado):")
print(ies_por_uf)
# Out:
# Quantidade de IES por estado (ordenado):
# SG_UF_IES
# SP    586
# MG    310
# PR    174
# BA    149
# RJ    128
# GO    127
# RS    120
# PE    118
# SC    102
# CE    101
# PA     77
# MT     72
# ES     69
# MA     65
# DF     61
# PI     48
# PB     45
# AM     32
# RO     32
# AL     30
# MS     30
# RN     26
# TO     23
# SE     22
# AP     15
# AC      9
# RR      9
# Name: count, dtype: int64

# %%
# Gráfico: Total de Matriculados por estado (QT_MAT)
mat_uf = df_merged.groupby('SG_UF_IES')['QT_MAT'].sum().sort_values(ascending=False)

plt.figure(figsize=(12, 6))
bars = plt.bar(mat_uf.index, mat_uf.values, color='#4CAF50', alpha=0.7)
plt.title('Total de Matriculados por Estado', fontsize=14, fontweight='bold')
plt.xlabel('Estado (UF)', fontsize=12)
plt.ylabel('Total de Matriculados', fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y', alpha=0.3)

# Adicionar labels em cada barra
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{int(height):,}',
             ha='center', va='bottom', fontsize=9, fontweight='bold')

plt.tight_layout()
plt.show()

print("\nTotal de matriculados por estado:")
print(mat_uf)
# Out:
# Total de matriculados por estado:
# SG_UF_IES
# SP    2331283
# PR    2080122
# SC    1065152
# RJ     948461
# MG     600342
# RS     313799
# PE     288671
# BA     281101
# CE     248858
# DF     214852
# GO     179294
# PA     164485
# MA     149089
# MS     134670
# AM     132211
# PB     132156
# ES     116979
# RN     108656
# PI     100004
# MT      99551
# AL      73751
# SE      59546
# TO      48264
# RO      45952
# AP      24627
# AC      19233
# RR      16108
# Name: QT_MAT, dtype: int64

# %%
# Gráficos: Top 10 IES com mais matriculados em SC e PR (barras empilhadas por modalidade)

# Incluir NO_IES no merge
df_merged_com_nome = pd.merge(df_cursos, df[['CO_IES', 'SG_UF_IES', 'NO_IES']], on='CO_IES', how='left')

# Filtrar por modalidade: 1 = Presencial, 2 = EAD
df_presencial = df_merged_com_nome[df_merged_com_nome['TP_MODALIDADE_ENSINO'] == 1]
df_ead = df_merged_com_nome[df_merged_com_nome['TP_MODALIDADE_ENSINO'] == 2]

# Filtrar e agrupar para SC
sc_presencial = df_presencial[df_presencial['SG_UF_IES'] == 'SC'].groupby('NO_IES')['QT_MAT'].sum()
sc_ead = df_ead[df_ead['SG_UF_IES'] == 'SC'].groupby('NO_IES')['QT_MAT'].sum()
sc_total = sc_presencial.add(sc_ead, fill_value=0)
sc_top10 = sc_total.sort_values(ascending=False).head(10)

# Filtrar e agrupar para PR
pr_presencial = df_presencial[df_presencial['SG_UF_IES'] == 'PR'].groupby('NO_IES')['QT_MAT'].sum()
pr_ead = df_ead[df_ead['SG_UF_IES'] == 'PR'].groupby('NO_IES')['QT_MAT'].sum()
pr_total = pr_presencial.add(pr_ead, fill_value=0)
pr_top10 = pr_total.sort_values(ascending=False).head(10)

# Criar figura com 2 subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

# Gráfico SC - Barras empilhadas
sc_presencial_vals = sc_top10.index.map(lambda x: sc_presencial.get(x, 0))
sc_ead_vals = sc_top10.index.map(lambda x: sc_ead.get(x, 0))

bars1 = ax1.barh(sc_top10.index, sc_presencial_vals, label='Presencial', color='#4A90E2', alpha=0.7)
bars1_ead = ax1.barh(sc_top10.index, sc_ead_vals, left=sc_presencial_vals, label='EAD', color='#FF6B6B', alpha=0.7)

ax1.set_title('Top 10 IES - Santa Catarina (SC)', fontsize=14, fontweight='bold')
ax1.set_xlabel('Total de Matriculados', fontsize=12)
ax1.invert_yaxis()
ax1.legend(loc='lower right')
ax1.grid(axis='x', alpha=0.3)

# Adicionar labels com total
for i, (ies, total) in enumerate(sc_top10.items()):
    ax1.text(total + 5000, i, f'{int(total):,}', 
             ha='left', va='center', fontsize=10, fontweight='bold')

# Gráfico PR - Barras empilhadas
pr_presencial_vals = pr_top10.index.map(lambda x: pr_presencial.get(x, 0))
pr_ead_vals = pr_top10.index.map(lambda x: pr_ead.get(x, 0))

bars2 = ax2.barh(pr_top10.index, pr_presencial_vals, label='Presencial', color='#4CAF50', alpha=0.7)
bars2_ead = ax2.barh(pr_top10.index, pr_ead_vals, left=pr_presencial_vals, label='EAD', color='#FFA500', alpha=0.7)

ax2.set_title('Top 10 IES - Paraná (PR)', fontsize=14, fontweight='bold')
ax2.set_xlabel('Total de Matriculados', fontsize=12)
ax2.invert_yaxis()
ax2.legend(loc='lower right')
ax2.grid(axis='x', alpha=0.3)

# Adicionar labels com total
for i, (ies, total) in enumerate(pr_top10.items()):
    ax2.text(total + 5000, i, f'{int(total):,}', 
             ha='left', va='center', fontsize=10, fontweight='bold')

plt.tight_layout()
plt.show()

print("\nTop 10 IES - Santa Catarina (SC):")
print(f"{'IES':<50} {'Presencial':<12} {'EAD':<12} {'Total':<12}")
print("-" * 88)
for ies in sc_top10.index:
    pres = sc_presencial.get(ies, 0)
    ead = sc_ead.get(ies, 0)
    total = pres + ead
    print(f"{ies:<48} {int(pres):<12,} {int(ead):<12,} {int(total):<12,}")

print("\nTop 10 IES - Paraná (PR):")
print(f"{'IES':<50} {'Presencial':<12} {'EAD':<12} {'Total':<12}")
print("-" * 88)
for ies in pr_top10.index:
    pres = pr_presencial.get(ies, 0)
    ead = pr_ead.get(ies, 0)
    total = pres + ead
    print(f"{ies:<48} {int(pres):<12,} {int(ead):<12,} {int(total):<12,}")
# Out:
# Top 10 IES - Santa Catarina (SC):
# IES                                                Presencial   EAD          Total
# ----------------------------------------------------------------------------------------
# CENTRO UNIVERSITÁRIO LEONARDO DA VINCI           357          709,337      709,694
# CENTRO UNIVERSITÁRIO ESTÁCIO DE SANTA CATARINA - ESTÁCIO SANTA CATARINA 4,727        96,708       101,435
# CENTRO UNIVERSITÁRIO FACVEST                     13,402       38,230       51,632
# UNIVERSIDADE FEDERAL DE SANTA CATARINA           25,589       676          26,265
# UNIVERSIDADE DO SUL DE SANTA CATARINA            11,977       5,675        17,652
# UNIVERSIDADE DO OESTE DE SANTA CATARINA          12,632       539          13,171
# UNIVERSIDADE DO VALE DO ITAJAÍ                   9,625        1,900        11,525
# UNIVERSIDADE DO EXTREMO SUL CATARINENSE          9,307        1,756        11,063
# FUNDAÇÃO UNIVERSIDADE DO ESTADO DE SANTA CATARINA 9,511        422          9,933
# ...
